# %%
import imageio as im
import numpy as np
import matplotlib.pyplot as plt

# %%
p1=im.imread('panda.jpg')

# %%
p1.shape
# Out:
# (316, 474, 3)

# %%
p2=p1.T

# %%
p2.shape
# Out:
# (3, 474, 316)

# %%
p3=p2[:,:,:3]

# %%
p3.shape
# Out:
# (3, 474, 3)

# %%
plt.imshow(p3)

# %%
plt.imshow(p1)

# %%
p1
# Out:
# Image([[[ 85, 118,  87],
#         [ 85, 118,  87],
#         [ 80, 113,  82],
#         ...,
#         [ 41,  50,  23],
#         [ 46,  55,  24],
#         [ 46,  55,  24]],
#
#        [[ 78, 111,  80],
#         [ 78, 111,  80],
#         [ 76, 109,  78],
#         ...,
#         [ 42,  51,  22],
#         [ 47,  56,  25],
#         [ 47,  57,  23]],
#
#        [[ 67, 101,  68],
#         [ 69, 103,  70],
#         [ 68, 102,  69],
#         ...,
#         [ 44,  55,  23],
#         [ 49,  60,  26],
#         [ 49,  61,  25]],
#
#        ...,
#
#        [[ 59, 100,  30],
#         [ 52,  88,  24],
#         [ 46,  77,  18],
#         ...,
#         [ 24,  27,  18],
#         [ 16,  19,  12],
#         [ 26,  29,  22]],
#
#        [[100, 140,  70],
#         [ 82, 119,  52],
#         [ 62,  93,  34],
#         ...,
#         [ 23,  26,  17],
#         [ 33,  36,  29],
#         [ 55,  58,  51]],
#
#        [[108, 148,  77],
#         [ 86, 123,  56],
#         [ 64,  95,  38],
# ...

# %%
p1[0][0]=0
p1[0][1]=255
p1[0][2]=0
p1[1][0]=0
p1[1][1]=255
p1[1][2]=0
p1[2][0]=0
p1[2][1]=255
p1[2][2]=0
p1[0][0][0]=40

# %%
# Out:
#   File "<ipython-input-80-65cb61440708>", line 1
#     for y in p1
#                ^
# SyntaxError: invalid syntax

# %%
plt.imshow(p1)

# %%
testimg = p1

# %%
testimg.shape
# Out:
# (316, 474, 3)

# %%
testimg[0][473][2]
# Out:
# 24

# %%
testimg.shape[0]
# Out:
# 316

# %%
for datapt in range(testimg.shape[0]):
    testimg[datapt][150][0] = 255

# %%
plt.imshow(testimg)

# %%
testimg[0][12][2]
# Out:
# 38
